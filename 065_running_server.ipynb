# %% [markdown]
# <br>
# <a href="https://www.nvidia.com/en-us/training/">
#     <div style="width: 55%; background-color: white; margin-top: 50px;">
#     <img src="https://dli-lms.s3.amazonaws.com/assets/general/nvidia-logo.png"
#          width="400"
#          height="186"
#          style="margin: 0px -25px -5px; width: 300px"/>
#     </div>
# </a>
# <h1 style="line-height: 1.4;"><font color="#76b900"><b>Rapid Application Development<br>using Large Language Models</b></h1>
# <h2><b>Notebook 6.5: [Advanced]</b> Running A GenAI Server</h2>
# <br>

# %% [markdown]
# This notebook complements **Notebook 6** by providing a dedicated notebook - and hence a dedicated event loop - to kickstart a series of GenAI microservices. This notebook will enable the local model APIs that will be used through the rest of the course, and features some more advanced tangents for those interested.
#
# As a prelude to **multi-GPU scaled deployment**, this notebook provides an oversimplified but functionally-sufficient example of an **on-device deployment workflow** which can be used to offer a standardized API for a consumer-grade or on-device deployment strategy. Since this course uses a single A100 instance and has many notebooks, you will run into problems if any one notebook overallocates model resources or fails to clear cache. As such, this is your change to deploy some smaller models once and call them as necessary.
#
# > **NOTE:** This notebook is an advanced tangent, should be ran to facilitate some later feature sets, and can be optionally understood if you have the time and interest. **Do not feel pressured to understand everything in this notebook and halt your progress because of it!**
#
# > **NOTE:** Before running this notebook, we recommend shutting down all active kernel instances from notebooks 5 and below. This notebook is intended to commandeer the majority of your A100 resources to launch multiple models.

# %% [markdown]
# <hr>
# <br>
#
# ## **Part 1:** Making A Custom Server For SDXL with FastAPI
#
# To start, we can make a server to wrap the SDXL API you experimented with at the end of Notebook 5. This is intended as an example application derived largely from the HuggingFace documented example ([narrative](https://huggingface.co/docs/diffusers/main/en/using-diffusers/create_a_server) and [code](https://github.com/huggingface/diffusers/blob/main/examples/server/server.py)), and provides a peek behind the curtain of inference server deployments without exploring too much of the complexity.
#
# **Warning:** FastAPI and server development is not within the scope of this class, and serves as a simplified example for those interested. Feel free to run the service as-is and assume the API will roughly work and operate reliably enough to fulfill the exercises, but we do not recommend using this solution for production. If you are interested in productionalizing an image generation server, consider using:
# - [Stable Diffusion NIM offerings](https://build.nvidia.com/stabilityai/stable-diffusion-3-medium) for self-hosted options.
# - [Automatic1111-style](https://github.com/NVIDIA/Stable-Diffusion-WebUI-TensorRT/tree/main) and [ComfyUI-style](https://github.com/comfyanonymous/ComfyUI_TensorRT) Stable-Diffusion WebUIs for streamlined accelerated deployments.
# - Hosted APIs like those offered by OpenAI and StabilityAI for non-self-hosted options.
# - Inference server projects like [vLLM](https://github.com/vllm-project/vllm) for inspirations on productionalized deployments.
#
# #### **Note The Following Features:**
# - **This is sufficient for a background server that mimics OpenAI's Dalle API for a single-user use-case.**
# - It roughly follows OpenAI's Dalle API with minimal functionality of generating a novel image.
# - Once the server is running, other services can call it via a port interface without having to reload or re-construct the resource allocated in the server.
#
# #### **Note The Following Critical Limitations:**
# - **It is explicitly not threadsafe!** This is outlined in the documentation narrative, and is important for multi-user use-cases. This server is only sufficient for a single user with relatively little allowed concurrency.
# - **There is no meaningful model discovery endpoint,** and it is generally non-trivial for an external user to understand how to use this server without digging into the code. This is omitted for brevity, since you have full access to the code.
# - **The server saves the file directly to a temporary file on the host system.** This is simplified for convenience, and is sufficient for meaningful interactions in a local deployment context.
#     - [OpenAI](https://platform.openai.com/docs/guides/images) would save such an image to a temporary publicly-accessible address. The caller can download the image and operate on it as usual.
#     - [NVIDIA NIM microservices](https://docs.api.nvidia.com/nim/reference/stabilityai-stable-diffusion-xl-infer), and thereby `build.nvidia.com`, returns a buffer in its response which can be decoded and interpretted as an image by the caller.

# %%
# %%writefile sdxl_app.py
import asyncio
import logging
import os
import random
import traceback
import uuid
from contextlib import asynccontextmanager
from time import time
from typing import Optional

import aiohttp
import torch
from fastapi import FastAPI, HTTPException
from pydantic import BaseModel
from diffusers import DiffusionPipeline

#########################################################################################
## Configuration and Logging Setup; global settings and checks
#########################################################################################
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger("TextToImageService")
MODEL_PATH = os.getenv("MODEL_PATH", "stabilityai/stable-diffusion-xl-base-1.0")
IMAGE_DIR = os.path.join("/dli/task/generated_images")
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

#########################################################################################
## FastAPI Application Setup
#########################################################################################
app = FastAPI()  # Initialize FastAPI app
globals = {      # Shared global resources
    "pipeline": None,
}

#########################################################################################
## Lifespan Context Manager: Dictates what all happens to construct and tear down server
#########################################################################################

@asynccontextmanager
async def lifespan(app: FastAPI):
    """
    Manages application lifespan:
    - Initializes shared resources (e.g., HTTP client, model pipeline).
    - Cleans up resources on shutdown.
    """
    if DEVICE != "cuda":
        raise RuntimeError("CUDA device is required for this application.")
    os.makedirs(IMAGE_DIR, exist_ok=True)  # Ensure image directory exists
    session = aiohttp.ClientSession()
    try:
        logger.info("Loading model on CUDA...")
        globals["pipeline"] = DiffusionPipeline.from_pretrained(
            MODEL_PATH, torch_dtype=torch.float16, use_safetensors=True, variant="fp16",
        ).to(DEVICE)
        globals["pipeline"].enable_xformers_memory_efficient_attention()
        # Perform a warm-up operation to force memory allocation
        dummy_prompt = "A blank test image" 
        generator = torch.Generator(device=DEVICE).manual_seed(0)
        _ = globals["pipeline"](dummy_prompt, num_inference_steps=1, generator=generator)
        ## Announce server is ready, list basic route info
        logger.info("Server Ready. Routes:")
        [logger.info(f" - {r} ({getattr(r, 'description', '')})") for r in app.routes]
        yield  ## Yields scope to allow server to run. On shutdown, will get scope back
    finally:
        await session.close()
        logger.warning("Application shutdown complete.")

app.router.lifespan_context = lifespan

#########################################################################################
## API Endpoints. These functions can be called from any user with access to server port
#########################################################################################

@app.get("/")
@app.post("/")
@app.options("/")
async def base():
    """Root endpoint for a simple health check or welcome message."""
    return {"message": "Welcome to Diffusers! Use this service to generate images from prompts."}

class TextToImageInput(BaseModel):
    """Schema for image generation input."""
    model: str
    prompt: str
    size: Optional[str] = None
    n: Optional[int] = None

@app.post("/v1/images/generations")
async def generate_image(image_input: TextToImageInput):
    """Endpoint to generate an image from a given prompt using the shared diffusion pipeline."""
    try:
        logger.info(f"[Request] {image_input}")
        if globals["pipeline"] is None:
            raise HTTPException(status_code=500, detail="Model pipeline is not initialized")
        generator = torch.Generator(device=DEVICE)
        generator.manual_seed(random.randint(0, 10000000))
        # Run pipeline in a thread pool to avoid blocking the event loop
        loop = asyncio.get_event_loop()
        pipe_kws = {**image_input.__dict__, "generator": generator}
        pipe_kws["num_images_per_prompt"] = pipe_kws.get("n") or 1
        start_time = time()
        output = await loop.run_in_executor(None, lambda: globals["pipeline"](**pipe_kws))
        end_time = time() - start_time
        image_urls = [save_image(img) for img in output.images]
        logger.info(f" - Generated {image_urls} over {end_time:.4f}s")
        return {"data": [{"url": url} for url in image_urls]}
    except Exception as e:
        logger.error(f"Error during image generation: {str(e)}")
        trace = f"{str(e)}\n{traceback.format_exc()}"
        raise HTTPException(status_code=500, detail=f"Image generation failed: {trace}")

def save_image(image) -> str:
    """Saves the generated image to the designated directory and returns its public URL."""
    filename = f"draw_{uuid.uuid4().hex[:8]}.png"
    image_path = os.path.join(IMAGE_DIR, filename)
    logger.info(f"Saving image to {image_path}")
    image.save(image_path)
    return image_path
        
#########################################################################################
## Standalone Execution for Local Development
#########################################################################################

if __name__ == "__main__":
    logger.info("Starting application...")
    uvicorn.run(app, host="0.0.0.0", port=8000, reload=True)
# Out:
# Writing sdxl_app.py

# %% [markdown]
# <hr>
# <br>
#
# ## **Part 2:** Getting Pre-Made Standardized Servers Using vLLM
#
# For a higher layer of abstraction, many people like to use inference services like [vLLM](https://github.com/vllm-project/vllm) to help deploy scalable and standardized LLM APIs. This framework automatically integrated with the Transformers model repository to download model weights and deserialize from config to pipeline. At the same time, it also offers abstractions for memory management, multi-user deployment, and API standards to wrap a resilient server around the loaded model resource.
#
# Using vLLM, we will deploy a small model that can run from within this notebook on our available resources: [Llama-3.1-Nemotron-Nano-VL-8B-V1](https://huggingface.co/nvidia/Llama-3.1-Nemotron-Nano-VL-8B-V1).
#
# This model, developed by NVIDIA for small language model use-cases, uses the multimodal fusion principles from Notebook 5 to perform joint reasoning with images and text. At the same time, it adopts the standard OpenAI-style API to largely interoperate with the likes of [**OpenAI's GPT-4o**](https://openai.com/index/hello-gpt-4o/), [**NVIDIA's NVLM**](https://arxiv.org/abs/2409.11402), and the open-sourced [**Llama 3.2 (2024)**](https://ai.meta.com/blog/llama-3-2-connect-2024-vision-edge-mobile-devices/).
#
# To deploy an inference server, the following command will work in our environment:
#
# ```sh
# vllm serve "nvidia/Llama-3.1-Nemotron-Nano-VL-8B-V1"
# --max_model_len 8192
# --gpu-memory-utilization 0.35
# --enforce-eager
# --port {port}
# --max-num-seqs 16
# --trust-remote-code
# --enable-auto-tool-choice
# --tool-parser-plugin llama_nemotron_toolcall_parser_no_streaming.py
# --tool-call-parser llama_nemotron_pythonic
# ```
#
# Note that these parameterizations are not meant to be recommendations, nor are they necessarily always good. Furthermore, there is still opportunities for resource contests and other issues. For productionalization, we highly recommend using NIM, which is a higher layer of abstraction over vLLM and the NVIDIA Triton acceleration framework.
#
#
#
# <details>
#
# <summary><b>Argument Details</b></summary>
#
# - **Port (9001 / 9002):** Defines the specific network port on which the model’s server listens. This lets other processes communicate with our server and send requests to it.
# - **Max Model Length (8192):** Sets the upper limit for the number of input tokens the model can process in a single operation, affecting the model's ability to handle longer sequences.
#     - Impacts resource allocation (since KV cache space needs to be allocated), increases maximum per-call inference time/resource use, and opens up opportunies for derailment.
# - **GPU Memory Utilization (0.4 / 0.5):** Dictates the percentage of the total available GPU memory that each model instance can use, ensuring that some GPU resources are left over for other processes.
#     - You may notice that our diffusion model server does not have such a configuration... because this a VLLM-specific parameter which is tightly paired with its engine wrapper. Implementing this for diffusion would need to be done manually.
#     - You may also note that 0.4 + 0.5 + diffusion resources (.17 usually) > 1. This tends to be ok in our specific context because the models require excess memory during construction. An actual productionalized solution should enforce stronger bounds if resilience is required.
# - **Max Number of Sequences (16):** Controls how many sequences the model can process simultaneously, optimizing both computational efficiency and response time during parallel requests.
# - **Enforce Eager:** Forces the model to execute operations immediately and in a sequential order, which simplifies debugging and execution traceability.
# - **Chat Template:** Implements a Jinja template for standardizing API responses, facilitating consistent and predictable interactions with the model.
#     - In reality, all LLMs that offer a a chat completions API have this format, which helps to convert an intuitive "message" format to "LLM input" format. It's important here because the version that is passed in [implemented here and advertised to work well for Llama 3.2](https://github.com/vllm-project/vllm/blob/main/examples/tool_chat_template_llama3.2_json.jinja), defines several non-default edge cases that enable things like function calling.
# - **Auto Tool Choice:** Employs automated logic to select the appropriate tools for function parsing and execution, adapting to the model's capabilities without manual configuration. This will be explored in more detail in **Notebook 7**
#
# </details>

# %% [markdown]
# <hr>
# <br>
#
# ## **Part 2.5:** BONUS: Wrangling These Servers With A Router
#
# Reading more into the OpenAI API standard, you will notice the following server-level requirements:
# - You should be able to discover what the models accessible to you from the server.
# - You should be able to communicate with the server in a standard and perdictable method.
#
# The is very useful because you can build software around these endpoints that adjusts itself to the available model pool and invokes the endpoints in a predictable fashion. However, we currently have two different endpoints for our two LLM models. This is a bit of a hinderance for calling these endpoints, as we can see in this invocation example:
#
# ```python
# from langchain_nvidia_ai_endpoints import ChatNVIDIA
# import os
#
# ## Saying Hello World to our model, ChatNVIDIA would auto-infer the name from discovery
# vlm = ChatNVIDIA(model="nvidia/Llama-3.1-Nemotron-Nano-VL-8B-V1", base_url="http://0.0.0.0:9002/v1")
# vlm = ChatNVIDIA(base_url="http://0.0.0.0:9002/v1")  ## equivalent
#
# llm.invoke("Hello World!")
# ```
#
# Wouldn't it be nicer if we could have them all aggregate under a single server?
#
# ```python
# ## But wouldn't it be nicer if we could have both models come from the same connector?
# os.environ["NVIDIA_BASE_URL"] = "http://0.0.0.0:9004/v1"
# llm = ChatNVIDIA(model="unsloth/Llama-3.2-3B-Instruct")  ## equivalent
# vlm = ChatNVIDIA(model="nvidia/Llama-3.1-Nemotron-Nano-VL-8B-V1")  ## equivalent
# ```
#
# Below, we define a basic router application which should help with this process. This is merely for convenience, but illustrates how one could aggregate multiple servers under one umbrella. This is, in fact, what `build.nvidia.com` does under the hood, and is a gateway to understand the `llm_client` microservice for those interested.

# %%
# %%writefile router_app.py
import asyncio
from contextlib import asynccontextmanager
from fastapi import FastAPI, HTTPException, Request
from fastapi.responses import Response, StreamingResponse, JSONResponse
import httpx
import json
import os
import traceback
from typing import Dict, Any, List, Tuple

# --- Configuration and Defaults ---

DEFAULTS = {
    "TIMEOUT": 60,  # Request timeout in seconds for backend calls
    "URLS": "0.0.0.0:9002,llm_client:9000",  # Backend URLs
    "FILTER_KEYWORDS": "meta,mistral,nvidia,llama-3.2,huggingfacetb",  # Model filter keywords
    "CACHE_REFRESH_INTERVAL": 3600, # Auto-refresh interval in seconds (1 hour)
}

def get_var(key: str) -> str:
    """Fetch a configuration variable, falling back to defaults."""
    return os.getenv(key, DEFAULTS.get(key, ""))

def get_urls() -> List[str]:
    """Parse and normalize backend URLs."""
    # Ensure all URLs start with 'http://' or 'https://'
    return [url if "://" in url else f"http://{url.strip()}" for url in get_var("URLS").split(",")]

def get_filter_keywords() -> List[str]:
    """Parse filter keywords for model filtering."""
    return [kw.strip().lower() for kw in get_var("FILTER_KEYWORDS").split(",")]

# --- Utilities for Model Discovery ---

async def fetch_models_from_server(server_url: str) -> Dict[str, Any]:
    """Fetch available models from a single backend server."""
    timeout_sec = int(get_var("TIMEOUT"))
    try:
        # Use a fresh client for each request
        async with httpx.AsyncClient(timeout=timeout_sec) as client:
            response = await client.get(f"{server_url}/v1/models")
            if response.status_code == 200:
                return {"server": server_url, "models": response.json().get("data", [])}
            return {"error": f"Failed to fetch models from {server_url} (Status: {response.status_code})"}
    except Exception as e:
        # Log error but don't re-raise, discovery should be fault-tolerant
        traceback.print_exc()
        return {"error": f"Exception during model discovery from {server_url}: {type(e).__name__} - {str(e)}"}

async def discover_models_and_cache(app: FastAPI) -> None:
    """Discover models from all backend servers and update the application cache."""
    print("--- Starting model discovery ---")
    
    tasks = [fetch_models_from_server(server) for server in get_urls()]
    results = await asyncio.gather(*tasks, return_exceptions=True)

    aggregated_models, errors = [], []
    for server, result in zip(get_urls(), results):
        if isinstance(result, dict) and "models" in result:
            # Tag models with their originating server
            for model in result["models"]:
                model["server"] = server
                aggregated_models.append(model)
        elif isinstance(result, dict) and "error" in result:
            errors.append(result["error"])
        else:
            errors.append(f"Unexpected result from {server}: {result}")
            
    # Apply filtering only to the discovered models
    keywords = get_filter_keywords()
    filtered_models = [
        model for model in aggregated_models 
        if any(kw in model.get("id", "").lower() for kw in keywords)
    ]
    
    # Update cache
    app.state.models = filtered_models
    app.state.discovery_errors = errors
    print(f"--- Model discovery complete. Found {len(filtered_models)} models. Errors: {len(errors)} ---")

# --- Application Lifecycle and Caching ---

@asynccontextmanager
async def lifespan(app: FastAPI):
    """Manage application startup and shutdown events."""
    print(f"Configured backend servers: {get_urls()}")
    print(f"Model filter keywords: {get_filter_keywords()}")
    
    # Initialize state
    app.state.models: List[Dict[str, Any]] = []
    app.state.discovery_errors: List[str] = []
    app.state.timeout = int(get_var("TIMEOUT"))
    
    # Initial model discovery
    await discover_models_and_cache(app)
    
    # Setup periodic refresh (Optional, but good for dynamic backends)
    # Ref: https://fastapi.tiangolo.com/tutorial/events/
    # loop = asyncio.get_event_loop()
    # app.state.refresh_task = loop.create_task(
    #     periodic_model_refresh(app, int(get_var("CACHE_REFRESH_INTERVAL")))
    # )

    yield # App is running

    # Cleanup on shutdown
    # app.state.refresh_task.cancel() 
    print("Application shutdown complete.")

async def periodic_model_refresh(app: FastAPI, interval: int) -> None:
    """Periodically refresh the model cache."""
    while True:
        await asyncio.sleep(interval)
        print("--- Initiating periodic model cache refresh ---")
        await discover_models_and_cache(app)

# Initialize FastAPI application and apply lifespan
app = FastAPI(lifespan=lifespan)

# --- Endpoints ---

@app.get("/v1/models")
@app.get("/v1/models/")
async def list_models():
    """List all available (and filtered) models from the cache."""
    response = {"object": "list", "data": app.state.models}
    if app.state.discovery_errors:
        response["warnings"] = app.state.discovery_errors
    return JSONResponse(content=response)

@app.get("/v1/models/refresh")
async def refresh_models():
    """Trigger a manual refresh of the model cache."""
    await discover_models_and_cache(app)
    return JSONResponse(content={"status": "Model cache refreshed.", "count": len(app.state.models)})

async def create_completion_base(request: Request, extension: str):
    """Core logic to forward requests to the target LLM server."""
    try:
        # 1. Parse Request
        content = await request.body()
        content_dict = json.loads(content.decode())
        model = content_dict.get("model")
        stream = content_dict.get("stream", False)

        # 2. Find Target Server from Cache
        # Use the cached model list, not a fresh discovery
        model_entry = next((m for m in app.state.models if m["id"] == model), None)
        if not model_entry:
            raise HTTPException(status_code=404, detail=f"Model '{model}' not found in the cache.")
        target_server = model_entry["server"]

        # 3. Prepare Outgoing Request
        # Filter headers to avoid issues with proxying
        headers = {
            key: value for key, value in request.headers.items()
            if key.lower() not in ["host", "content-length", "transfer-encoding"] # content-length will be set by httpx
        }
        
        call_kws = {
            "url": f"{target_server}/v1/{extension}",
            "headers": headers,
            "data": content
        }

        # 4. Handle Non-Streaming Use Case
        if not stream:
            # Using a fresh httpx client for each request
            async with httpx.AsyncClient(timeout=app.state.timeout) as client:
                try:
                    response = await client.post(**call_kws)
                except httpx.TimeoutException:
                    raise HTTPException(status_code=408, detail="Request timed out from the backend server.")

                # Filter response headers
                filtered_headers = {
                    key: value for key, value in response.headers.items() 
                    if key.lower() not in ["content-length", "content-encoding", "transfer-encoding"]
                }
                
                return Response(
                    content=response.content, 
                    status_code=response.status_code, 
                    headers=filtered_headers
                )

        # 5. Handle Streaming Use Case
        async def stream_response_generator():
            # Use a fresh httpx client for streaming
            async with httpx.AsyncClient(timeout=app.state.timeout) as client:
                try:
                    # Use client.stream() for chunked/streaming responses
                    async with client.stream("POST", **call_kws) as response:
                        # Check initial status code
                        if response.status_code != 200:
                            # If not 200, read content and raise error (or return a non-stream Response)
                            response_bytes = await response.aread()
                            # Raising HTTPException inside a generator can be tricky, 
                            # so we stop the stream and return a standard Response object from the main function.
                            # We yield the exception details instead of raising.
                            yield {"status_code": response.status_code, "content": response_bytes, "headers": response.headers}
                            return # Stop the generator
                        
                        # Stream the chunks
                        async for chunk in response.aiter_bytes():
                            yield chunk

                except httpx.TimeoutException:
                    raise HTTPException(status_code=408, detail="Streaming request timed out from the backend server.")
                except Exception as e:
                    # Catch connection errors, etc., during streaming
                    print(f"Streaming error: {e}")
                    raise HTTPException(status_code=500, detail=f"Streaming error: {str(e)}")


        # Process the generator
        agen = stream_response_generator()
        first_chunk = await agen.__anext__()

        if isinstance(first_chunk, dict) and "status_code" in first_chunk:
            # Handle non-200 response from the backend
            filtered_headers = {
                key: value for key, value in first_chunk["headers"].items() 
                if key.lower() not in ["content-length", "content-encoding", "transfer-encoding"]
            }
            return Response(
                content=first_chunk["content"], 
                status_code=first_chunk["status_code"], 
                headers=filtered_headers
            )
        else:
            # 200 OK, start the StreamingResponse
            # Re-insert the first chunk before yielding the rest of the generator
            async def re_insert_first_chunk_and_stream(first_chunk, agen):
                yield first_chunk
                async for chunk in agen:
                    yield chunk

            return StreamingResponse(
                re_insert_first_chunk_and_stream(first_chunk, agen), 
                media_type='text/event-stream'
            )

    except json.JSONDecodeError:
        raise HTTPException(status_code=400, detail="Invalid JSON in request body.")
    except HTTPException:
        # Re-raise explicit HTTP exceptions
        raise
    except Exception as e:
        traceback.print_exc()
        raise HTTPException(
            status_code=500,
            detail=f"An unexpected error occurred: {str(e)}"
        )


@app.post("/v1/{path:path}")
@app.get("/v1/{path:path}") # Support GET requests if the backend does (e.g., /v1/embeddings endpoint that uses GET)
async def handle_request(request: Request, path: str):
    """Forwards requests based on the path to the appropriate OpenAPI endpoint."""
    return await create_completion_base(request, extension=path)

# --- Health Check ---

@app.get("/health")
async def health_check():
    """Simple health check endpoint."""
    return {"status": "healthy"}
# Out:
# Writing router_app.py

# %% [markdown]
# <hr>
# <br>
#
# ## **Part 3**: Kickstarting The Servers In Our Notebook
#
# We've now explained how these servers are constructed, both behind the scenes and at a surface-level. **This is an advanced topic, so it's ok if this doesn't quite stick.** What's important is that you understand that:
# - **It's possible to kickstart many LLM servers that can be used by one or many users.**
# - **These servers can prevent resources from being allocated multiple times over.**
# - **For good compatability, these servers usually follow a standard or easy-to-use API.**
#
# We will need these features through the rest of the course, so please run the code cell below to kickstart your environment. This will kickstart each of your models, one at a time, until :9003 gets occupied with your Llama 3.2 model deployment. Once again, this process is documented here for your own reference, and is not necessary to understand as part of the course learning objectives.
#
# **NOTE:**
# - We recommend shutting down previous kernels to free up all of your resources for this action.
# - If you encounter an issue of freeze-up, please interrupt the kernel (square button) and try again.
# - This command will produce a running log. For that reason, there is no text below the following cell. Please return back to **Notebook 6** once you're done.

# %%
import asyncio
import uvicorn
import subprocess
import nest_asyncio
from colorama import Fore, Style
import traceback

# Allow nested asyncio event loops
nest_asyncio.apply()

async def run_cmd(cmd, label, color, start_event=None, end_event=None, end_trigger="http://0.0.0.0"):
    if start_event:
        await start_event.wait()  # Wait for the previous process to signal it's ready
    print(f"\nSTARTING {color}[{label}]{Style.RESET_ALL}")
    process = await asyncio.create_subprocess_shell(
        " ".join(cmd.strip().split()),
        stdout=asyncio.subprocess.PIPE,
        stderr=asyncio.subprocess.PIPE,
    )
    async def read_stream(stream, color, label):
        while True:
            line = await stream.readline()
            if not line: break
            decoded_line = line.decode().strip()
            print(f"{color}[{label}]{Style.RESET_ALL} {decoded_line}")
            if end_event and end_trigger and end_trigger in decoded_line:
                end_event.set()  # Signal that this process is ready when port is shown
    stdout_task = asyncio.create_task(read_stream(process.stdout, color, label))
    stderr_task = asyncio.create_task(read_stream(process.stderr, Fore.RED, f"{label}-ERR"))
    await asyncio.wait([stdout_task, stderr_task])
    await process.wait()

async def run_vlm(port=9000, **kwargs):
    await run_cmd(f"""
    vllm serve "nvidia/Llama-3.1-Nemotron-Nano-VL-8B-V1"
    --max_model_len 8192
    --gpu-memory-utilization 0.35
    --enforce-eager
    --port {port}
    --max-num-seqs 16
    --trust-remote-code
    --enable-auto-tool-choice
    --tool-parser-plugin llama_nemotron_toolcall_parser_no_streaming.py
    --tool-call-parser llama_nemotron_pythonic
    """, label="VLM", color=Fore.BLUE, **kwargs) 

async def run_sdxl(port=9000, **kwargs):
    await run_cmd(
        f"PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True uvicorn sdxl_app:app --host 0.0.0.0 --port {port} --log-level info 2>&1",
        label="SDXL1.0", color=Fore.CYAN, **kwargs) 

async def run_router(port=9000, **kwargs):
    await run_cmd(f"uvicorn router_app:app --host 0.0.0.0 --port {port} --log-level info 2>&1",
    label="ROUTER", color=Fore.MAGENTA, **kwargs) 
    
# Create event objects to coordinate the start of each process
events = [None, None]
def get_ev_pair(events=events):
    events[:2] = [events[1], asyncio.Event()]
    return {"start_event": events[0], "end_event": events[1]}

print("Starting Processes")
await asyncio.gather(
    run_vlm     (9002, **get_ev_pair()),
    run_sdxl    (9003, **get_ev_pair()),
    run_router  (9004, **get_ev_pair()),
)
# Out:
# Starting Processes
#
# STARTING [VLM]
# [VLM] INFO 07-27 14:22:35 [__init__.py:216] Automatically detected platform cuda.
# [VLM] (APIServer pid=1454) INFO 07-27 14:22:40 [api_server.py:1839] vLLM API server version 0.11.0
# [VLM] (APIServer pid=1454) INFO 07-27 14:22:40 [utils.py:233] non-default args: {'model_tag': 'nvidia/Llama-3.1-Nemotron-Nano-VL-8B-V1', 'port': 9002, 'enable_auto_tool_choice': True, 'tool_call_parser': 'llama_nemotron_pythonic', 'tool_parser_plugin': 'llama_nemotron_toolcall_parser_no_streaming.py', 'model': 'nvidia/Llama-3.1-Nemotron-Nano-VL-8B-V1', 'trust_remote_code': True, 'max_model_len': 8192, 'enforce_eager': True, 'gpu_memory_utilization': 0.35, 'max_num_seqs': 16}
# [VLM-ERR] (APIServer pid=1454) /usr/local/lib/python3.12/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
# [VLM-ERR] (APIServer pid=1454)   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# [VLM-ERR] (APIServer pid=1454) /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
# [VLM-ERR] (APIServer pid=1454)   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# [VLM] (APIServer pid=1454) INFO 07-27 14:22:55 [model.py:547] Resolved architecture: Llama_Nemotron_Nano_VL
# [VLM] (APIServer pid=1454) INFO 07-27 14:22:55 [model.py:1510] Using max model len 8192
# [VLM] (APIServer pid=1454) INFO 07-27 14:22:55 [scheduler.py:205] Chunked prefill is enabled with max_num_batched_tokens=2048.
# [VLM] (APIServer pid=1454) INFO 07-27 14:22:55 [__init__.py:381] Cudagraph is disabled under eager mode
# [VLM] INFO 07-27 14:23:01 [__init__.py:216] Automatically detected platform cuda.
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:08 [core.py:644] Waiting for init message from front-end.
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:08 [core.py:77] Initializing a V1 LLM engine (v0.11.0) with config: model='nvidia/Llama-3.1-Nemotron-Nano-VL-8B-V1', speculative_config=None, tokenizer='nvidia/Llama-3.1-Nemotron-Nano-VL-8B-V1', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=True, dtype=torch.bfloat16, max_seq_len=8192, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, disable_custom_all_reduce=False, quantization=None, enforce_eager=True, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_fallback=False, disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser=''), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None), seed=0, served_model_name=nvidia/Llama-3.1-Nemotron-Nano-VL-8B-V1, enable_prefix_caching=True, chunked_prefill_enabled=True, pooler_config=None, compilation_config={"level":0,"debug_dump_path":"","cache_dir":"","backend":"","custom_ops":[],"splitting_ops":null,"use_inductor":true,"compile_sizes":[],"inductor_compile_config":{"enable_auto_functionalized_v2":false},"inductor_passes":{},"cudagraph_mode":0,"use_cudagraph":true,"cudagraph_num_of_warmups":0,"cudagraph_capture_sizes":[],"cudagraph_copy_inputs":false,"full_cuda_graph":false,"use_inductor_graph_partition":false,"pass_config":{},"max_capture_size":0,"local_cache_dir":null}
# [VLM] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [VLM] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [VLM] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [VLM] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [VLM] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [VLM] [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:09 [parallel_state.py:1208] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, TP rank 0, EP rank 0
# [VLM] (EngineCore_DP0 pid=1629) WARNING 07-27 14:23:10 [topk_topp_sampler.py:66] FlashInfer is not available. Falling back to the PyTorch-native implementation of top-p & top-k sampling. For the best performance, please install FlashInfer.
# [VLM] (EngineCore_DP0 pid=1629) WARNING 07-27 14:23:10 [__init__.py:2227] The following intended overrides are not keyword args and will be dropped: {'truncation'}
# [VLM] (EngineCore_DP0 pid=1629) WARNING 07-27 14:23:10 [processing.py:1089] NemotronVLProcessor did not return `BatchFeature`. Make sure to match the behaviour of `ProcessorMixin` when implementing custom processors.
# [VLM] (EngineCore_DP0 pid=1629) WARNING 07-27 14:23:10 [__init__.py:2227] The following intended overrides are not keyword args and will be dropped: {'truncation'}
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:10 [gpu_model_runner.py:2602] Starting to load model nvidia/Llama-3.1-Nemotron-Nano-VL-8B-V1...
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:10 [gpu_model_runner.py:2634] Loading model from scratch...
# [VLM-ERR] (EngineCore_DP0 pid=1629) /usr/local/lib/python3.12/dist-packages/timm/models/registry.py:4: FutureWarning: Importing from timm.models.registry is deprecated, please import via timm.models
# [VLM-ERR] (EngineCore_DP0 pid=1629)   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.models", FutureWarning)
# [VLM-ERR] (EngineCore_DP0 pid=1629) /usr/local/lib/python3.12/dist-packages/timm/models/layers/__init__.py:49: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
# [VLM-ERR] (EngineCore_DP0 pid=1629)   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# [VLM-ERR] (EngineCore_DP0 pid=1629) No pretrained configuration specified for vit_huge_patch16_224 model. Using a default. Please add a config to the model pretrained_cfg registry or pass explicitly.
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:12 [__init__.py:381] Cudagraph is disabled under eager mode
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:12 [cuda.py:366] Using Flash Attention backend on V1 engine.
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:12 [weight_utils.py:392] Using model weights format ['*.safetensors']
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:33 [weight_utils.py:413] Time spent downloading weights for nvidia/Llama-3.1-Nemotron-Nano-VL-8B-V1: 21.521377 seconds
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:33 [weight_utils.py:450] No model.safetensors.index.json found in remote.
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:02<00:00,  2.22s/it]
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:02<00:00,  2.22s/it]
# [VLM-ERR] (EngineCore_DP0 pid=1629)
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:36 [default_loader.py:267] Loading weights took 2.78 seconds
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:37 [gpu_model_runner.py:2653] Model loading took 16.2775 GiB and 25.922684 seconds
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:37 [gpu_model_runner.py:3344] Encoder cache will be initialized with a budget of 3330 tokens, and profiled with 1 image items of the maximum feature size.
# [VLM] (EngineCore_DP0 pid=1629) WARNING 07-27 14:23:37 [__init__.py:2227] The following intended overrides are not keyword args and will be dropped: {'truncation'}
# [VLM] (EngineCore_DP0 pid=1629) WARNING 07-27 14:23:37 [__init__.py:2227] The following intended overrides are not keyword args and will be dropped: {'truncation'}
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:38 [gpu_worker.py:298] Available KV cache memory: 10.99 GiB
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:38 [kv_cache_utils.py:1087] GPU KV cache size: 90,032 tokens
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:38 [kv_cache_utils.py:1091] Maximum concurrency for 8,192 tokens per request: 10.99x
# [VLM] (EngineCore_DP0 pid=1629) WARNING 07-27 14:23:38 [cudagraph_dispatcher.py:106] cudagraph dispatching keys are not initialized. No cudagraph will be used.
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:38 [core.py:210] init engine (profile, create kv cache, warmup model) took 1.59 seconds
# [VLM] (EngineCore_DP0 pid=1629) WARNING 07-27 14:23:39 [__init__.py:2227] The following intended overrides are not keyword args and will be dropped: {'truncation'}
# [VLM] (EngineCore_DP0 pid=1629) INFO 07-27 14:23:39 [__init__.py:381] Cudagraph is disabled under eager mode
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:39 [loggers.py:147] Engine 000: vllm cache_config_info with initialization after num_gpu_blocks is: 5627
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:39 [api_server.py:1634] Supported_tasks: ['generate']
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:40 [serving_responses.py:166] "auto" tool choice has been enabled please note that while the parallel_tool_calls client option is preset for compatibility reasons, it will be ignored.
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:40 [serving_chat.py:99] "auto" tool choice has been enabled please note that while the parallel_tool_calls client option is preset for compatibility reasons, it will be ignored.
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [api_server.py:1912] Starting vLLM API server 0 on http://0.0.0.0:9002
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:34] Available routes are:
#
# STARTING [SDXL1.0]
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /openapi.json, Methods: GET, HEAD
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /docs, Methods: GET, HEAD
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /docs/oauth2-redirect, Methods: GET, HEAD
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /redoc, Methods: GET, HEAD
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /health, Methods: GET
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /load, Methods: GET
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /ping, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /ping, Methods: GET
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /tokenize, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /detokenize, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /v1/models, Methods: GET
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /version, Methods: GET
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /v1/responses, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /v1/responses/{response_id}, Methods: GET
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /v1/responses/{response_id}/cancel, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /v1/chat/completions, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /v1/completions, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /v1/embeddings, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /pooling, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /classify, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /score, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /v1/score, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /v1/audio/transcriptions, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /v1/audio/translations, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /rerank, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /v1/rerank, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /v2/rerank, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /scale_elastic_ep, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /is_scaling_elastic_ep, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /invocations, Methods: POST
# [VLM] (APIServer pid=1454) INFO 07-27 14:23:41 [launcher.py:42] Route: /metrics, Methods: GET
# [VLM-ERR] (APIServer pid=1454) INFO:     Started server process [1454]
# [VLM-ERR] (APIServer pid=1454) INFO:     Waiting for application startup.
# [VLM-ERR] (APIServer pid=1454) INFO:     Application startup complete.
# [SDXL1.0] INFO:     Started server process [1861]
# [SDXL1.0] INFO:     Waiting for application startup.
# [SDXL1.0] INFO:TextToImageService:Loading model on CUDA...
# Loading pipeline components...: 100%|██████████| 7/7 [00:00<00:00,  8.81it/s]0<?, ?it/s]
# 100%|██████████| 1/1 [00:00<00:00,  2.84it/s]?, ?it/s]
# [SDXL1.0] INFO:TextToImageService:Server Ready. Routes:
# [SDXL1.0] INFO:TextToImageService: - Route(path='/openapi.json', name='openapi', methods=['GET', 'HEAD']) ()
# [SDXL1.0] INFO:TextToImageService: - Route(path='/docs', name='swagger_ui_html', methods=['GET', 'HEAD']) ()
# [SDXL1.0] INFO:TextToImageService: - Route(path='/docs/oauth2-redirect', name='swagger_ui_redirect', methods=['GET', 'HEAD']) ()
# [SDXL1.0] INFO:TextToImageService: - Route(path='/redoc', name='redoc_html', methods=['GET', 'HEAD']) ()
# [SDXL1.0] INFO:TextToImageService: - APIRoute(path='/', name='base', methods=['OPTIONS']) (Root endpoint for a simple health check or welcome message.)
# [SDXL1.0] INFO:TextToImageService: - APIRoute(path='/', name='base', methods=['POST']) (Root endpoint for a simple health check or welcome message.)
# [SDXL1.0] INFO:TextToImageService: - APIRoute(path='/', name='base', methods=['GET']) (Root endpoint for a simple health check or welcome message.)
# [SDXL1.0] INFO:TextToImageService: - APIRoute(path='/v1/images/generations', name='generate_image', methods=['POST']) (Endpoint to generate an image from a given prompt using the shared diffusion pipeline.)
# [SDXL1.0] INFO:     Application startup complete.
# [SDXL1.0] INFO:     Uvicorn running on http://0.0.0.0:9003 (Press CTRL+C to quit)
#
# STARTING [ROUTER]
# [ROUTER] INFO:     Started server process [1934]
# [ROUTER] INFO:     Waiting for application startup.
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:42642 - "GET /v1/models HTTP/1.1" 200 OK
# [ROUTER] INFO:     Application startup complete.
# [ROUTER] INFO:     Uvicorn running on http://0.0.0.0:9004 (Press CTRL+C to quit)
# [VLM] (APIServer pid=1454) INFO 07-27 14:24:51 [loggers.py:127] Engine 000: Avg prompt throughput: 0.7 tokens/s, Avg generation throughput: 29.2 tokens/s, Running: 1 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.3%, Prefix cache hit rate: 0.0%
# [VLM] (APIServer pid=1454) INFO 07-27 14:25:01 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 57.2 tokens/s, Running: 1 reqs, Waiting: 0 reqs, GPU KV cache usage: 1.0%, Prefix cache hit rate: 0.0%
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:59746 - "POST /v1/completions HTTP/1.1" 200 OK
# [ROUTER] Configured backend servers: ['http://0.0.0.0:9002', 'http://llm_client:9000']
# [ROUTER] Model filter keywords: ['meta', 'mistral', 'nvidia', 'llama-3.2', 'huggingfacetb']
# [ROUTER] --- Starting model discovery ---
# [ROUTER] --- Model discovery complete. Found 64 models. Errors: 0 ---
# [ROUTER] INFO:     127.0.0.1:51782 - "POST /v1/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:54190 - "GET /v1/models HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 14:25:11 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 29.9 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [VLM] (APIServer pid=1454) INFO 07-27 14:25:21 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [VLM] (APIServer pid=1454) INFO 07-27 14:25:26 [chat_utils.py:560] Detected the chat template content format to be 'openai'. You can set `--chat-template-content-format` to override this.
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:40196 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:58592 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) WARNING 07-27 14:25:30 [protocol.py:93] The following fields were present in the request but ignored: {'stop_token'}
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:40210 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:58608 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 14:25:31 [loggers.py:127] Engine 000: Avg prompt throughput: 7.5 tokens/s, Avg generation throughput: 3.9 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 0.0%
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:38934 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42022 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:38946 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42036 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:38956 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:38972 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:38976 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:38984 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42050 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42066 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42076 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42068 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 14:25:41 [loggers.py:127] Engine 000: Avg prompt throughput: 68.2 tokens/s, Avg generation throughput: 120.2 tokens/s, Running: 16 reqs, Waiting: 33 reqs, GPU KV cache usage: 0.9%, Prefix cache hit rate: 41.9%
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39012 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42112 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39046 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42174 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39108 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42216 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39074 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42194 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:38990 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42078 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:38992 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42094 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39026 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42128 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39036 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42158 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39098 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42206 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39000 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39020 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39030 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39058 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39064 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39088 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39118 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42192 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42102 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42196 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42226 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42144 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42180 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42118 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39208 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42296 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39128 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42232 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39142 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42236 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39178 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42258 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39164 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42256 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39148 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42238 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39276 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42376 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39202 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42280 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39264 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42360 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39162 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42252 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39224 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42300 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39250 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42352 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39190 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42270 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39248 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42340 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39240 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42338 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39280 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42390 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39234 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42330 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39314 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42414 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39230 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42314 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39270 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42368 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39286 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42394 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39298 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42404 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39408 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42508 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39324 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42418 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39328 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42432 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39344 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42436 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39358 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42438 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39362 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42444 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39372 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39396 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42492 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42454 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39386 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42470 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39388 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42484 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39412 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:42524 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:56040 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 14:25:51 [loggers.py:127] Engine 000: Avg prompt throughput: 92.8 tokens/s, Avg generation throughput: 477.8 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 50.1%
# [VLM] (APIServer pid=1454) INFO 07-27 14:26:01 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 50.1%
# [ROUTER] INFO:     127.0.0.1:48336 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [ROUTER] INFO:     127.0.0.1:55894 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:53098 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:44572 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:37930 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:44588 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:37942 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 14:37:31 [loggers.py:127] Engine 000: Avg prompt throughput: 297.2 tokens/s, Avg generation throughput: 11.7 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 18.2%
# [VLM] (APIServer pid=1454) INFO 07-27 14:37:41 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 18.2%
# [ROUTER] INFO:     127.0.0.1:37956 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [ROUTER] INFO:     127.0.0.1:50514 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [ROUTER] INFO:     127.0.0.1:39668 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [ROUTER] INFO:     127.0.0.1:40368 - "GET /v1/models HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:40372 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [ROUTER] INFO:     127.0.0.1:50804 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [SDXL1.0] INFO:TextToImageService:[Request] model='whichever' prompt='An awesome white cat playing in the snow' size='512x512' n=4
# 100%|██████████| 50/50 [00:21<00:00,  2.37it/s], ?it/s]
# [SDXL1.0] INFO:TextToImageService:Saving image to /dli/task/generated_images/draw_4de65f1c.png
# [SDXL1.0] INFO:TextToImageService:Saving image to /dli/task/generated_images/draw_17ac3037.png
# [SDXL1.0] INFO:TextToImageService:Saving image to /dli/task/generated_images/draw_a81cd470.png
# [SDXL1.0] INFO:TextToImageService:Saving image to /dli/task/generated_images/draw_9c6bd1e8.png
# [SDXL1.0] INFO:TextToImageService: - Generated ['/dli/task/generated_images/draw_4de65f1c.png', '/dli/task/generated_images/draw_17ac3037.png', '/dli/task/generated_images/draw_a81cd470.png', '/dli/task/generated_images/draw_9c6bd1e8.png'] over 22.1677s
# [SDXL1.0] INFO:     127.0.0.1:33338 - "POST /v1/images/generations HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:50258 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [ROUTER] INFO:     127.0.0.1:57110 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [SDXL1.0] INFO:TextToImageService:[Request] model='whichever' prompt="Show me a magical scene with large language models! I'd love to see it all fleshed out with shades of nvidia green!" size='512x512' n=4
# 100%|██████████| 50/50 [00:21<00:00,  2.37it/s], ?it/s]
# [SDXL1.0] INFO:TextToImageService:Saving image to /dli/task/generated_images/draw_e4a6bf65.png
# [SDXL1.0] INFO:TextToImageService:Saving image to /dli/task/generated_images/draw_bf5961e7.png
# [SDXL1.0] INFO:TextToImageService:Saving image to /dli/task/generated_images/draw_b93ca805.png
# [SDXL1.0] INFO:TextToImageService:Saving image to /dli/task/generated_images/draw_ce78bc3b.png
# [SDXL1.0] INFO:TextToImageService: - Generated ['/dli/task/generated_images/draw_e4a6bf65.png', '/dli/task/generated_images/draw_bf5961e7.png', '/dli/task/generated_images/draw_b93ca805.png', '/dli/task/generated_images/draw_ce78bc3b.png'] over 22.1616s
# [SDXL1.0] INFO:     127.0.0.1:48332 - "POST /v1/images/generations HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:39148 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [ROUTER] INFO:     127.0.0.1:44622 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [ROUTER] INFO:     127.0.0.1:55862 - "GET /v1/models HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:55870 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [ROUTER] INFO:     127.0.0.1:58660 - "GET /v1/models HTTP/1.1" 200 OK
# [ROUTER] INFO:     127.0.0.1:52066 - "GET /v1/models HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) WARNING 07-27 15:21:12 [processing.py:1089] NemotronVLProcessor did not return `BatchFeature`. Make sure to match the behaviour of `ProcessorMixin` when implementing custom processors.
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:52832 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 15:21:22 [loggers.py:127] Engine 000: Avg prompt throughput: 284.1 tokens/s, Avg generation throughput: 26.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 11.3%
# [VLM] (APIServer pid=1454) INFO 07-27 15:21:32 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 11.3%
# [ROUTER] INFO:     127.0.0.1:59668 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [ROUTER] INFO:     127.0.0.1:33266 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:60440 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 15:30:02 [loggers.py:127] Engine 000: Avg prompt throughput: 284.3 tokens/s, Avg generation throughput: 26.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 8.3%
# [VLM] (APIServer pid=1454) INFO 07-27 15:30:12 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 8.3%
# [ROUTER] INFO:     127.0.0.1:53312 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [ROUTER] INFO:     127.0.0.1:42048 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 15:31:52 [loggers.py:127] Engine 000: Avg prompt throughput: 181.9 tokens/s, Avg generation throughput: 3.0 tokens/s, Running: 1 reqs, Waiting: 0 reqs, GPU KV cache usage: 2.1%, Prefix cache hit rate: 7.2%
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:57152 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 15:32:02 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 31.2 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 7.2%
# [VLM] (APIServer pid=1454) INFO 07-27 15:32:12 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 7.2%
# [ROUTER] INFO:     127.0.0.1:45506 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 15:32:42 [loggers.py:127] Engine 000: Avg prompt throughput: 28.3 tokens/s, Avg generation throughput: 4.5 tokens/s, Running: 1 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.4%, Prefix cache hit rate: 7.2%
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:58506 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 15:32:52 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 4.9 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 7.2%
# [VLM] (APIServer pid=1454) INFO 07-27 15:33:02 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 7.2%
# [ROUTER] INFO:     127.0.0.1:40646 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 15:33:22 [loggers.py:127] Engine 000: Avg prompt throughput: 79.5 tokens/s, Avg generation throughput: 6.7 tokens/s, Running: 1 reqs, Waiting: 0 reqs, GPU KV cache usage: 1.0%, Prefix cache hit rate: 6.9%
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:39008 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 15:33:32 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 1.9 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 6.9%
# [VLM] (APIServer pid=1454) INFO 07-27 15:33:42 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 6.9%
# [ROUTER] INFO:     127.0.0.1:40498 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [ROUTER] INFO:     127.0.0.1:56522 - "POST /v1/chat/completions HTTP/1.1" 408 Request Timeout
# [VLM] (APIServer pid=1454) INFO 07-27 15:44:02 [loggers.py:127] Engine 000: Avg prompt throughput: 284.3 tokens/s, Avg generation throughput: 10.5 tokens/s, Running: 1 reqs, Waiting: 0 reqs, GPU KV cache usage: 3.3%, Prefix cache hit rate: 23.3%
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:34262 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 15:44:12 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 15.5 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 23.3%
# [VLM] (APIServer pid=1454) INFO 07-27 15:44:22 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 23.3%
# [ROUTER] INFO:     127.0.0.1:59248 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:60436 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 15:45:12 [loggers.py:127] Engine 000: Avg prompt throughput: 181.9 tokens/s, Avg generation throughput: 34.2 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 31.0%
# [VLM] (APIServer pid=1454) INFO 07-27 15:45:22 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 31.0%
# [ROUTER] INFO:     127.0.0.1:50730 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:60370 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 15:46:12 [loggers.py:127] Engine 000: Avg prompt throughput: 28.3 tokens/s, Avg generation throughput: 9.4 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 32.0%
# [VLM] (APIServer pid=1454) INFO 07-27 15:46:22 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 32.0%
# [ROUTER] INFO:     127.0.0.1:33250 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO:     127.0.0.1:53870 - "POST /v1/chat/completions HTTP/1.1" 200 OK
# [VLM] (APIServer pid=1454) INFO 07-27 15:47:22 [loggers.py:127] Engine 000: Avg prompt throughput: 79.5 tokens/s, Avg generation throughput: 8.6 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 34.8%
# [VLM] (APIServer pid=1454) INFO 07-27 15:47:32 [loggers.py:127] Engine 000: Avg prompt throughput: 0.0 tokens/s, Avg generation throughput: 0.0 tokens/s, Running: 0 reqs, Waiting: 0 reqs, GPU KV cache usage: 0.0%, Prefix cache hit rate: 34.8%
# [ROUTER] INFO:     127.0.0.1:59194 - "POST /v1/chat/completions HTTP/1.1" 200 OK

# %% [markdown]
# <a href="https://www.nvidia.com/en-us/training/">
#     <div style="width: 55%; background-color: white; margin-top: 50px;">
#     <img src="https://dli-lms.s3.amazonaws.com/assets/general/nvidia-logo.png"
#          width="400"
#          height="186"
#          style="margin: 0px -25px -5px; width: 300px"/>
#     </div>
# </a>
